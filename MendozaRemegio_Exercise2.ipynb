# %% [markdown]
# <a href="https://colab.research.google.com/github/rems1-coder/CCMACLRL_COM242ML./blob/main/MendozaRemegio_Exercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 2
#
# Simple Linear Regression
#
# **Instructions:**
#
# Build a Simple Linear Regression model to study the linear relationship between the years of experience and salary.
#
# <img src="https://media2.giphy.com/media/67ThRZlYBvibtdF9JH/200w.gif?cid=6c09b952x78udp8ynvf71q2iximtwq0egwludug1qo7qgla2&ep=v1_gifs_search&rid=200w.gif&ct=g">

# %% [markdown]
# 1. Import the necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# 2. Load the salary.csv file

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/exercise2/Salary_dataset.csv', index_col=0)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 3. Print the first 5 rows of the dataset

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %% [markdown]
# 4. Display the general information of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 720.0 bytes

# %% [markdown]
# 5. Visualize the data by creating a scatter plot

# %%
plt.scatter(df['YearsExperience'], df['Salary'])
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# 6. Split the dataset into a training set and test set

# %%
X = df[['YearsExperience']]
y = df['Salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# 7. Create an new instance of a linear regression model

# %%
model = LinearRegression()

# %% [markdown]
# 8. Train and test the model using the training set and test set

# %%
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %% [markdown]
# 9. Print the equation of the line
#
# - Display the slope
# - Display the intercept
# - Display the equation of the line

# %%
slope = model.coef_[0]
intercept = model.intercept_

print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"Equation of the line: Salary = {slope:.2f} * YearsExperience + {intercept:.2f}")
# Out:
# Slope: 9312.575126729185
# Intercept: 25849.841637955273
# Equation of the line: Salary = 9312.58 * YearsExperience + 25849.84

# %% [markdown]
# 10. Draw the Regression Line

# %%
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.scatter(X_test, y_test, color='green', label='Test data')
plt.plot(X_train, model.predict(X_train), color='red', label='Regression Line')
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %% [markdown]
# 11. Compute the Sum of Square Error (SSE)

# %%
sse = np.sum((y_test - y_pred) ** 2)
print(f"Sum of Square Error (SSE): {sse:.2f}")
# Out:
# Sum of Square Error (SSE): 76940473.79

# %% [markdown]
# 12. Compute the $R^2$

# %%
r2 = r2_score(y_test, y_pred)
print(f"R-squared (R2): {r2:.4f}")
# Out:
# R-squared (R2): 0.9882
